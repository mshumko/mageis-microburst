# %% [markdown]
# Here I develop the diffusion curves for the magEIS microbust

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
# %matplotlib inline

# %% [markdown]
# Define physical constants and relativistic $\beta$ and $\gamma$, functions of kinetic energy for electrons

# %%
c = 3.0E8 # m/s
mu_0 = 1.26E-6 # H·m−1 or N·A−2
eps0 = 8.85E-12 # F/m
m_p = 1.7E-27 # kg
m_e = 9.1E-31 # kg
q_e = -1.6E-19 # C
beta = lambda Ek: np.sqrt(1-(Ek/511+1)**(-2))
gamma = lambda Ek: np.sqrt(1-beta(Ek)**2)**(-1/2)

# %% [markdown]
# Define a dipole magnetic field function in terms of L and $\lambda$

# %%
B0 = 31.2E-6 # Tesla from Schultz and Lanzerotti 

# MagB is from Eq. 1.23 in Schultz and Lanzerotti for a dipole field.
magB = lambda mlat, L: (B0/L**3)*np.sqrt(1 + 3*np.power(np.sin(np.deg2rad(mlat)), 2))/np.cos(np.deg2rad(mlat))**6

# %% [markdown]
# Define plasma frequency $\omega_{pe}$, gyrofrequency $\omega_{ce}$, and the chorus |k| (assume parallel propagation and cold plasma dispersion relation).
#
# These equations are parametrized in terms of L shell and magnetic latitude using a dipole magnetic field

# %%
wce = lambda λ, Ldip: np.abs(q_e)*magB(λ, Ldip)/m_e
n_e = lambda n0, λ = None: n0 # Electron number density. Currently constant, but can assume a complex function.
wpe = lambda n0, λ = None: np.sqrt(n_e(n0, λ)*q_e**2/(m_e*eps0))
magk = lambda w, n0, λ, Ldip: (w/c)*np.sqrt(1 - wpe(n0, λ)**2/(w*(w - wce(λ, Ldip))))

# %%
def p(vPerp, vParallel):
    """
    Map velocity to momentum space
    v is two lists, vperp and vparallel.
    """
    pPerp = vPerp/np.sqrt(1 - (vPerp**2 + vParallel**2)/c**2)/c
    pParallel = vParallel/np.sqrt(1 - (vPerp**2 + vParallel**2)/c**2)/c
    return pPerp, pParallel

# %%
mlatt = 0
LL = 4
nn = 60E6
ww = 0.1*wce(mlatt, LL)
print('{0:0.2e}'.format(magk(ww, nn, mlatt, LL)))
print('w_pe/w_ce = ', wpe(nn, mlatt)/wce(mlatt, LL))
# Out:
# 4.86e-04
# w_pe/w_ce =  5.09506895485

# %% [markdown]
# Draw ellipses for the resonance curves

# %%
u = ww/magk(ww, nn, mlatt, LL)/wce(mlatt, LL) # omega/k
# Map the center and axies to momentum space
pPerpCenter, pParallelCenter = p(0, u*(ww/c)**2/(u**2 + (ww/c)**2))
pPerpAxis, z = p(c*((1 - u**2))**0.5, 0)
z, pParallelAxis = p(0, u*c)

print('{0:0.2e}'.format(u*c))
print('{0:0.2e}'.format((c*(1 - u**2))**0.5))
print(pPerpAxis, pParallelAxis)
ellipse = Ellipse((pPerpCenter, pParallelCenter), pPerpAxis, pParallelAxis, fill=True)
fig, ax = plt.subplots()
ax.add_artist(ellipse)
ellipse.set_facecolor(np.random.rand(3))
ax.set(xlim = (0, 4), ylim = (0,4))
# Out:
# 6.17e+10
# nan
# nan nan
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in double_scalars
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# [(0, 4), (0, 4)]

# %% [markdown]
# Assuming a resonance, define the perpendicular velocity given a set of conditions and parallel velocity

# %%
def resCurveVperp(vParallel, w, n0, λ, L, n = 1):
    """
    This function defines the perpendicular velocity of a resonant particle with arbitrary resonance number.
    """
    A = c**2*(w**2 + (magk(w, n0, λ, L)*vParallel)**2 - 2*w*vParallel*magk(w, n0, λ, L))/(wce(λ, L)*n)**2
    return np.sqrt(c**2 - vParallel**2 - A)

def resCurveVparallel(vPerp, w, n0, λ, L, n = 1):
    A = magk(w, n0, λ, L)*w
    B = n*np.sqrt(-(magk(w, n0, λ, L)*wce(λ, L)*vPerp)**2 + (magk(w, n0, λ, L)*wce(λ, L))**2 + (w*wce(λ, L))**2
                 + (n*wce(λ, L)*vPerp)**2 - n**2*wce(λ, L)**4)
    C = magk(w, n0, λ, L)**2 - (n*wce(λ, L))**2
    return (A + B)/C, (A - B)/C

# %% [markdown]
# Visualize a few resonance curves

# %%
vParallel = c*np.linspace(0, 0.6)
mlat = 20
L = 6
n0 = 0.5E6 # Density at the time
#w =  # Half the gyro frequency
print('w_pe/w_ce = ', wpe(n0, mlat)/wce(mlat, L))




vPerp = resCurveVperp(vParallel, 0.1*wce(mlat, L), n0, mlat, L)
pPerp, pParallel = p(vPerp, vParallel)
plt.plot(pPerp, pParallel, label = r'$0.1 \ \Omega_{ce}$')
#plt.plot(vPerp, vParallel)

#vPerp = resCurveVperp(vParallel, 0.3*wce(mlat, L), n0, mlat, L)
#pPerp, pParallel = p([vPerp, vParallel])
#plt.plot(pPerp, pParallel, label = r'$0.3 \ \Omega_{ce}$')

#vPerp = resCurveVperp(vParallel, 0.6*wce(mlat, L), n0, mlat, L)
#pPerp, pParallel = p([vPerp, vParallel])
#plt.plot(pPerp, pParallel, label = r'$0.6 \ \Omega_{ce}$')

#plt.ylim((0, 1))
#plt.xlim((0, 4))
plt.xlabel(r'$p_{\perp}/m_e c$')
plt.ylabel(r'$p_{||}/m_e c$')
plt.title(r'Resonance Curves for $\omega_{pe} / \omega_{ce} = $' + str(round(wpe(n0, mlat)/wce(mlat, L), 2)))
plt.legend()
# Out:
# w_pe/w_ce =  0.929889105504

# %%
print('vPerp, pPerp, vParallel, pParallel')
for i in range(len(vParallel)):
   if np.isnan(vPerp[i]):
       continue
   print('{0:0.2e}, {1:0.2f}, {2:0.2e}, {3:0.2f}'.format(vPerp[i], pPerp[i], vParallel[i], pParallel[i]))
# Out:
# vPerp, pPerp, vParallel, pParallel
# 2.98e+08, 9.95, 0.00e+00, 0.00
# 2.99e+08, 10.37, 3.67e+06, 0.13
# 2.99e+08, 10.82, 7.35e+06, 0.27
# 2.99e+08, 11.31, 1.10e+07, 0.42
# 2.99e+08, 11.84, 1.47e+07, 0.58
# 2.98e+08, 12.43, 1.84e+07, 0.76
# 2.98e+08, 13.07, 2.20e+07, 0.97
# 2.98e+08, 13.79, 2.57e+07, 1.19
# 2.98e+08, 14.58, 2.94e+07, 1.44
# 2.98e+08, 15.47, 3.31e+07, 1.72
# 2.97e+08, 16.48, 3.67e+07, 2.04
# 2.97e+08, 17.62, 4.04e+07, 2.40
# 2.96e+08, 18.94, 4.41e+07, 2.82
# 2.96e+08, 20.48, 4.78e+07, 3.31
# 2.95e+08, 22.28, 5.14e+07, 3.88
# 2.95e+08, 24.45, 5.51e+07, 4.57
# 2.94e+08, 27.08, 5.88e+07, 5.41
# 2.93e+08, 30.36, 6.24e+07, 6.46
# 2.92e+08, 34.56, 6.61e+07, 7.81
# 2.92e+08, 40.13, 6.98e+07, 9.60
# 2.91e+08, 47.90, 7.35e+07, 12.10
# 2.90e+08, 59.46, 7.71e+07, 15.82
# 2.89e+08, 78.53, 8.08e+07, 21.97
# 2.88e+08, 115.97, 8.45e+07, 34.04
# 2.87e+08, 223.03, 8.82e+07, 68.57
# 2.86e+08, 3199.76, 9.18e+07, 1028.92
# 2.84e+08, 256.86, 9.55e+07, 86.26
# 2.83e+08, 122.90, 9.92e+07, 43.06
# 2.82e+08, 80.51, 1.03e+08, 29.39
# 2.80e+08, 59.71, 1.07e+08, 22.68
# 2.79e+08, 47.34, 1.10e+08, 18.70
# 2.77e+08, 39.14, 1.14e+08, 16.06
# 2.76e+08, 33.30, 1.18e+08, 14.19
# 2.74e+08, 28.92, 1.21e+08, 12.78
# 2.73e+08, 25.52, 1.25e+08, 11.70
# 2.71e+08, 22.80, 1.29e+08, 10.83
# 2.69e+08, 20.58, 1.32e+08, 10.12
# 2.67e+08, 18.72, 1.36e+08, 9.53
# 2.65e+08, 17.14, 1.40e+08, 9.03
# 2.63e+08, 15.79, 1.43e+08, 8.60
# 2.61e+08, 14.61, 1.47e+08, 8.23
# 2.59e+08, 13.58, 1.51e+08, 7.90
# 2.56e+08, 12.67, 1.54e+08, 7.62
# 2.54e+08, 11.85, 1.58e+08, 7.37
# 2.52e+08, 11.12, 1.62e+08, 7.14
# 2.49e+08, 10.45, 1.65e+08, 6.93
# 2.47e+08, 9.85, 1.69e+08, 6.75
# 2.44e+08, 9.30, 1.73e+08, 6.58
# 2.41e+08, 8.79, 1.76e+08, 6.43
# 2.38e+08, 8.32, 1.80e+08, 6.29

# %% [markdown]
# Assuming a constant phase velocity, the following function maps the electron parallel velocity into perpendicular velocity along a diffusion curve (conservation of kinetic energy implied). Free parameters are the phase velocity and

# %%
def calcDiffusionCurveConstantU(v_parallel,  u_0, v_0):
    """
    This function returns the perpendicular velocity from the diffusion
    equation given in Eq. 6 in Summers et al. 1998. 

    Input velocity units must be divided by c!

    THIS FUNCTION ASSUMES THAT THE WAVE PHASE VELOCITY IS CONSTANT!
    """
    numerator = ( -(1 - (u_0*v_0)**2)*v_parallel**2 + 
        2*u_0*(1 - v_0**2)*v_parallel + v_0**2 + u_0**2)
    denomimator = 1 - u_0**2
    return np.sqrt(numerator/denomimator)

# %%
#def diffusionCurveNonRel(v_parallel, omega, n, mlat, L):
#    u_ph = c/np.sqrt(1 - wpe(n, mlat)**2/(omega*wce(mlat, L)*(omega*wce(mlat, L) - wce(mlat, L))))
#    
#    return np.sqrt(u_ph*v_parallel - v_parallel**2)

#v_parallel = np.linspace(0, 0.9*c)
#omega = 0.4
#n = 1E5
#mlat = 30
#L = 6
#diffusionCurveNonRel(v_parallel, omega, n, mlat, L)
#plt.plot(p(diffusionCurveNonRel(v_parallel, omega, n, mlat, L)), p(v_parallel))
#calcDiffusionCurveConstantUWrapper(v_parallel, E, B, n, omega)

# %% [markdown]
# Define the Alfven speed and the alpha parameter from Summers 1998 paper to calculate the phase velocity
# $\omega$ must be normalized to the elctron gyrofrequency, and the B field in units of nT and electron number density, n in #/cc

# %%
v_a = lambda B, n: 1e-9*B/np.sqrt((1e6)*mu_0*n*m_p)
summersAlpha = lambda B, n: (m_p/m_e)*(v_a(n, B)/c)**2
u = lambda omega, B, n: np.sqrt(summersAlpha(B, n)*omega*(1 - omega))

# %%
Ek = lambda v, Erest = 511: Erest*(1/np.sqrt(1 - v**2/c**2) - 1)

# %%
# Map velocity to relativistic momentum
#pVelocity = lambda v, Erest = 511: np.sqrt(Ek(v, Erest)*(Ek(v, Erest) + 2*Erest))/Erest
#p = lambda v: v/(c*np.sqrt(1 - v**2/c**2))
#p = lambda Ek, Erest = 511: np.sqrt(Ek*(Ek + 2*Erest))/Erest

# %% [markdown]
# Define a generic diffusion curve calculator wrapper

# %%
def calcDiffusionCurveConstantUWrapper(v_parallel, E, B, n, omega):
    """
    Energy must be in keV!
    """
    u_ph = u(omega, B, n)
    v_0 = beta(E)
    v_perp = calcDiffusionCurveConstantU(v_parallel,  u_ph, v_0)
    
    #filter out the nan's
    validV = np.where(np.logical_not(np.isnan(v_perp)))[0]
    return v_perp[validV], v_parallel[validV]

# %% [markdown]
# Now play around with the parameters to get a sence of what the curves look like

# %%
#E = [34, 54, 78, 108, 143, 182, 223]
E = np.arange(100, 1500, 100)
#B = 180 # nT # From the magEphem file at the time of the microburst
n = 3 # cm^-3 # Just a guess
omega = 0.4# wave frequency/elctron gyrofrequncy
λ = 30
L = 4
harmonic = 1
print('fpe/fce = {}'.format(wpe(1E6*n, λ)/wce(λ, L)))

v_parallel = np.linspace(0, 0.7)
params = 'n_e = {} cm^-3 \nB = {} nT \nomega = {} \nmLat = {} \nL = {}'.format(
    n, round(magB(λ, L)*1E9, 0), omega, λ, L)

fig=plt.figure(figsize=(10, 10), dpi= 80, facecolor='w', edgecolor='k')
for e in E:
    # Calculate diffusion curve
    v_perpFlt, v_parallelFlt = calcDiffusionCurveConstantUWrapper(v_parallel, e, magB(λ, L)*1E9, n, omega)
    p_perpFlt, p_parallelFlt = p(v_perpFlt*c, v_parallelFlt*c)
    # Plot the results
    plt.plot(p_perpFlt, p_parallelFlt) #, label = '{} keV'.format(e))

# Calculate and plot resonance curves
v_perp_res = resCurveVperp(c*v_parallel, wce(λ, L)*0.1, 1E6*n, λ, L, n = harmonic)/c
pPerp, pPrallel = p(v_perp_res*c, v_parallel*c)
plt.plot(pPerp, pPrallel, 'k--', label = 'omega = 0.1 resonance curve')
#v_perp_res = resCurveVperp(c*v_parallel, wce(λ, L)*0.6, 1E6*n, λ, L, n = harmonic)/c
#plt.plot(v_perp_res*c, v_parallel*c, 'k:', label = 'omega = 0.6 resonance curve')

#for i in range(50):
#    print(v_perp_res[i], v_parallel[i])

plt.xlabel(r'$v_{\perp}/m_e c$'); plt.ylabel(r'$v_{||}/m_e c$')
plt.text(0, 0, params, ha = 'left', fontsize = 15)
plt.legend()
plt.axes().set_ylim(0, 4)
plt.axes().set_xlim(0, 4)
plt.grid(True)
#plt.axes().set_aspect('equal')
# Out:
# fpe/fce = 0.3633288079492032
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in sqrt
#   del sys.path[0]
